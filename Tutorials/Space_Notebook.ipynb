# %% [markdown]
# # Space Project:
# ![image.png](attachment:a480ee33-ea83-49d3-8727-663ab082d8d5.png)
#
# At 9.200.3120 Quelaag Universal Time, the space vessel SS Galantic encountered an unknown space anomaly approximately 3.21 light years from Proxima Centauri. A distress signal was sent out, and emergency transport
# services were sent out to rescue survivors.
#
# In your role as the head data scientist for the intergalactic transit authoritv, you were contacted to investigate and audit the results of the rescue. Some survivors and activists believe this rescue wasn't conducted fairly.
#
# You've been called in to investigate.

# %%
import pandas as pd
import altair_express as alx

# %%
url = ""
df = pd.read_csv()

# %% [markdown]
# ## Sensemaking and Profiling: Getting a sense of the data
# Use this section to get a sense for the data profile. When you're ready, write your answers the questions in the markdown cell below.
# ### Questions:
#
# What did you notice from the dataset? Any Insights?
#
# What is your assessment of the data quality?

# %% [markdown]
# ## Exploration and Discovery:
# Use this section to explore the data a bit more and get a sense for what might be interesting aspects to dig into.
#
# When you're ready, list some of your insights from your exploration.

# %% [markdown]
# ## Investigation:
# Given some of the potential insights you had about the data, pick one and do additional investigations related to it.

# %% [markdown]
# ## Followups:

# %% [markdown]
# Approximately how many people were in cryosleep?

# %% [markdown]
# What is the survival rate of people who's home planet was Mars?

# %%
# !!!! When you're done, please hit the "Save" button in the toolbar !!!
