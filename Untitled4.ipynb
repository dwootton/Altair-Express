# %%
import plotly.express as px
import seaborn as sns
import pandas as pd
import altair_express as alx

# %%
df = pd.read_csv('https://gist.githubusercontent.com/dwootton/6e45d15f0b6936bd8c54df7849930117/raw/c7bdac122b3babce87b6a2f000c71f66c8fba0c2/final_space_titanic.csv')
fig = px.scatter(x=df.CryoSleep, y=df.Destination)
fig.show()

# %%
df
# Out:
#       Unnamed: 0 PassengerId HomePlanet CryoSleep     Cabin    Destination  \
# 0              0     0809_04       Mars     False   F/151/S    TRAPPIST-1e
# 1              1     3531_02       Mars      True   F/731/P    TRAPPIST-1e
# 2              2     1387_01       Mars     False    E/85/P    TRAPPIST-1e
# 3              3     8581_02     Europa      True   C/323/S    TRAPPIST-1e
# 4              4     4137_01      Earth     False   F/778/S    55 Cancri e
# ...          ...         ...        ...       ...       ...            ...
# 4995        4995     4006_01      Earth      True   G/660/S    55 Cancri e
# 4996        4996     2758_01      Earth      True   G/446/P  PSO J318.5-22
# 4997        4997     9077_01      Earth     False  F/1856/P    55 Cancri e
# 4998        4998     6671_01       Mars      True  F/1279/S    TRAPPIST-1e
# 4999        4999     6806_01      Earth     False  G/1104/S    TRAPPIST-1e
#
# ...

# %%
alx.scatterplot(df, x='RoomService',y='ShoppingMall',color='rgba(70, 130, 180,0.6)')
# Out:
# alt.Chart(...)

# %%
alx.lineplot?
# Out:
# Signature:
# alx.lineplot(
#     data=None,
#     x=None,
#     y=None,
#     y_axis=Axis({
#
# }),
#     x_axis=Axis({
#
# }),
#     color=None,
#     effects=None,
#     width=200,
#     height=200,
# )
# Docstring: <no docstring>
# File:      ~/Documents/GitHub/altair_express/altair_express/altair_express/relational.py
# Type:      function
