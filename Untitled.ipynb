# %%
import pandas as pd
import altair_express as alx

# %%
url = "https://gist.githubusercontent.com/dwootton/f2d4d19849a7e5bd4a4e20bd17343a66/raw/9752c3fb17aa45624cf782f4ac0dd284162e3559/space_titanic.csv"
df = pd.read_csv(url)

# %%
import altair_express as alx
from vega_datasets import data
df = data.cars()

alx.highlight_brush() + alx.hist(df,x='Horsepower')
# Out:
# alt.LayerChart(...)

# %%
alx.filter_type(target='Name')+alx.hist(df,x='Age')
# Out:
# alt.Chart(...)

# %%
df.loc[df['Name'].str.split().str.len() == 2, 'last name'] = df['Name'].str.split().str[-1]

# %%
filter_brush = alx.filter_brush()
overview = filter_brush+ alx.countplot(df,x='last name').interactive()
detail = alx.countplot(df,x='last name',effects={filter:filter_brush})
overview & detail
# Out:
# alt.VConcatChart(...)

# %%
best_survival_rate = 0 
best_name = ''
survival_rates = []
for name in df['last name'].value_counts().index:
    num_survived = df[df['last name']==name]['Transported'].sum()
    total_num =len(df[df['last name']==name]['Transported'])
    survival_rate = num_survived /total_num
    if total_num >= 3:
        survival_rates.append(survival_rate)
    if survival_rate >= best_survival_rate and total_num > 1:
        best_survival_rate = survival_rate
        best_name = name

    #['Myling','Clugete','Cartez','Dister']

# %%
survival = pd.DataFrame({'last name, binned by survival_rate': survival_rates})
alx.hist(survival,x='last name, binned by survival_rate')
# Out:
# alt.Chart(...)

# %%
df[df['last name']==df['last name'].value_counts().index[0]]['Transported'].sum()
# Out:
# 4

# %%
df[df['last name']==df['last name'].value_counts().index[0]]['Transported'].sum()/len(df[df['last name']==df['last name'].value_counts().index[0]]['Transported'])
# Out:
# 0.3333333333333333
