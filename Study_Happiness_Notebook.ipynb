# %% [markdown]
# # Happiness Project:
# ![image.png](attachment:02a7245d-9662-4af3-8958-b49f5be28fd1.png)![image.png](attachment:06e52748-e411-41af-a77a-2dc97d2b3a0d.png)
#
# Over the past 5 years, an international organization has surveyed the populations of most countries and computed aggregate information related to each country's populace happiness.
#
# In your role as head data scientist for the UN global development project, you know that this data may hold secrets on how the UN should advocate for future development. It is the goal of the project to better understand the conditions that lead to happiness so future initiatives can improve the happiness of the world's citizens.
#
# You've been called in to investigate.
#
# Data Dictionary: https://happiness-report.s3.amazonaws.com/2022/Appendix_1_StatiscalAppendix_Ch2.pdf

# %%
import pandas as pd

# %%
url = "" # Hit the "Start" button in the toolbar and fill in your user code and then in the second prompt, list your notebook as "Happiness" to get the data
df = pd.read_csv(url)

# %% [markdown]
# ## Sensemaking and Profiling: Getting a sense of the data
# Use this section to get a sense for the data profile. When you're ready, write your answers the questions in the markdown cell below.
# ### Questions:
#
# What did you notice from the dataset? Any Insights>?
#
# What is your assessment of the data quality?

# %% [markdown]
# ### Answers:
#
# What did you notice from the dataset? Any Insights?

# %% [markdown]
# enter answers here

# %% [markdown]
# What is your assessment of the data quality?

# %%
enter answers here

# %% [markdown]
# ## Exploration and Discovery:
# Use this section to explore the data a bit more and get a sense for what might be interesting aspects to dig into.
#
# When you're ready, list some of your insights from your exploration.

# %% [markdown]
# List any interesting insights from your exploration:

# %% [markdown]
# - Enter
# - Insights
# - Here

# %% [markdown]
# ## Investigation:
# Given some of the potential insights you had about the data, pick one and do additional investigations related to it.

# %%
# !!!! When you're done, please hit the "Save" button in the toolbar !!!
